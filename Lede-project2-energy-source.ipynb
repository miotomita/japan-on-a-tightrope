# %% [markdown]
# **Key World Energy Statistics 2021, IEA**
#
# https://www.iea.org/reports/key-world-energy-statistics-2021

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
url = 'https://github.com/miotomita/lede-project2/blob/main/WorldEnergyBalancesHighlights2021.xlsx?raw=true'

# %%
df = pd.read_excel(url, sheet_name='TimeSeries_1971-2020',skiprows=1)

# %%
df.head()
# Out:
#      Country                   Product                                   Flow  \
# 0  Australia  Coal, peat and oil shale                        Production (PJ)
# 1  Australia  Coal, peat and oil shale                           Imports (PJ)
# 2  Australia  Coal, peat and oil shale                           Exports (PJ)
# 3  Australia  Coal, peat and oil shale               Total energy supply (PJ)
# 4  Australia  Coal, peat and oil shale  Electricity, CHP and heat plants (PJ)
#
#        NoCountry                     NoProduct  \
# 0  01. Australia  01. Coal, peat and oil shale
# 1  01. Australia  01. Coal, peat and oil shale
# 2  01. Australia  01. Coal, peat and oil shale
# 3  01. Australia  01. Coal, peat and oil shale
# 4  01. Australia  01. Coal, peat and oil shale
#
#                                       NoFlow         1971         1972  \
# 0                        01. Production (PJ)  1368.251838  1648.414248
# 1                           02. Imports (PJ)            0            0
# 2                           03. Exports (PJ)  -541.424001  -614.718001
# 3               04. Total energy supply (PJ)    884.29747   923.250159
# 4  05. Electricity, CHP and heat plants (PJ)  -516.538554   -569.92192
#
#           1973         1974  ...         2011         2012         2013  \
# 0  1685.223676  1640.362098  ...  9782.067241  10272.36221  11074.77871
# 1            0            0  ...     6.755636     3.635428      2.57749
# 2  -738.939398  -745.382946  ... -7720.391726 -8171.019358 -9101.059456
# 3    945.54188    928.32307  ...  2013.814178  1968.848884  1831.204342
# 4  -577.900491  -617.948468  ... -1789.197177 -1769.932048 -1650.413411
#
#           2014         2015         2016         2017         2018  \
# 0  11950.78794  12501.00154  12223.55369  12264.16248   12034.6322
# 1     5.287409     6.978797     6.829994     7.916741    12.735731
# 2  -10166.8869  -10634.4478  -10552.5051  -10248.0298  -10333.3662
# 3   1736.61351  1797.035545  1863.051458  1872.030679  1797.650326
# 4 -1561.052148  -1622.70676 -1668.865761 -1651.517169 -1573.934618
#
#           2019 2020 Provisional
# 0  12596.41582      12331.64135
# 1    17.037944        19.629498
# 2  -10629.0366       -10541.275
# 3  1744.105366      1648.774748
# 4 -1531.523087               ..
#
# [5 rows x 56 columns]

# %%
df.Flow.unique()
# Out:
# array(['Production (PJ)', 'Imports (PJ)', 'Exports (PJ)',
#        'Total energy supply (PJ)',
#        'Electricity, CHP and heat plants (PJ)',
#        'Oil refineries, transformation (PJ)',
#        'Total final consumption (PJ)', 'Industry (PJ)', 'Transport (PJ)',
#        'Residential (PJ)', 'Commercial and public services (PJ)',
#        'Other final consumption (PJ)', 'Electricity output (GWh)'],
#       dtype=object)

# %%
df.Product.unique()
# Out:
# array(['Coal, peat and oil shale', 'Crude, NGL and feedstocks',
#        'Oil products', 'Natural gas', 'Nuclear', 'Renewables and waste',
#        'Electricity', 'Heat', 'Total', 'Fossil fuels',
#        'Renewable sources'], dtype=object)

# %%
supply_jp = df[(df.Country=='Japan')&(df.Flow=='Total energy supply (PJ)')]

# %%
supply_jp = supply_jp.set_index('Product').loc[:,1971:]

# %%
supply_jp = supply_jp.rename(columns={'2020 Provisional':2020}).astype(float)

# %%
supply_jp.iloc[:-1]
# Out:
#                                   1971         1972         1973        1974  \
# Product
# Coal, peat and oil shale   2346.367695  2291.936699  2422.572601   2575.5621
# Crude, NGL and feedstocks  7907.203501  8616.965002    10301.016    9975.752
# Oil products                418.076598   505.872199   121.176798  138.435499
# Natural gas                 138.810599   144.228599   212.450399  281.482198
# Nuclear                      87.272728   103.636363   105.894547  214.898182
# Renewables and waste        303.119999   306.360001   250.084803  301.247997
# Electricity                          0            0            0           0
# Heat                                 0            0            0           0
#
#                                   1975         1976         1977         1978  \
# Product
# Coal, peat and oil shale   2390.283748  2365.444146  2228.519922  1950.049273
# Crude, NGL and feedstocks  9479.427501  9768.591502   10051.6565  9738.296499
# Oil products                  1.142599   389.003999   459.959101   677.350402
# Natural gas                   323.1981     379.8585     465.5043   656.115299
# Nuclear                     274.090909   371.770909   345.370907   647.050911
# Renewables and waste        303.861599      308.124   273.484803     273.7692
# Electricity                          0            0            0            0
# Heat                                 0            0            0            0
#
#                                   1979         1980  ...         2011  \
# Product                                              ...
# Coal, peat and oil shale   2144.350919  2493.470093  ...    4551.7491
# Crude, NGL and feedstocks   10029.1225    9136.8505  ...  7522.421245
# Oil products                723.454401   646.898298  ...  1082.835199
# Natural gas                   779.5584   896.056202  ...  4177.283705
# Nuclear                     767.923634   900.992728  ...  1110.120034
# Renewables and waste        323.074799     350.2512  ...   939.550083
# Electricity                          0            0  ...            0
# Heat                                 0            0  ...            0
#
#                                   2012         2013         2014         2015  \
# Product
# Coal, peat and oil shale   4753.500303    5127.7548  4974.071993  5043.360414
# Crude, NGL and feedstocks  7579.637844  7555.270174  7168.253967  7050.988406
# Oil products                1148.34229   856.543315   811.395267   662.639167
# Natural gas                4394.723911  4401.743638  4463.992868  4195.702874
# Nuclear                     173.884507   101.484544            0   102.952202
# Renewables and waste        919.846944   986.605239  1028.268819  1098.849202
# Electricity                          0            0            0            0
# Heat                                 0            0            0            0
#
#                                   2016         2017         2018         2019  \
# Product
# Coal, peat and oil shale   4963.725598  4980.577765  4903.231379  4829.848075
# Crude, NGL and feedstocks  6951.643815  6744.983166   6365.23019  6203.076452
# Oil products                470.734271   643.831969     603.0102   468.378982
# Natural gas                4257.832537  4224.271169  4076.525478  3855.319564
# Nuclear                      197.01782   359.037196   708.317498   695.770647
# Renewables and waste       1135.798667  1237.473053  1296.081483  1335.780541
# Electricity                          0            0            0            0
# Heat                                 0            0            0            0
#
#                                   2020
# Product
# Coal, peat and oil shale   4684.391312
# Crude, NGL and feedstocks  5062.512549
# Oil products               1110.894835
# Natural gas                4054.010928
# Nuclear                     422.745655
# Renewables and waste       1376.778444
# Electricity                          0
# Heat                                 0
#
# [8 rows x 50 columns]

# %%
source
# Out:
#      year                    Product       supply
# 152  1990   Coal, peat and oil shale  3229.715063
# 153  1990  Crude, NGL and feedstocks  8499.544035
# 154  1990               Oil products  1916.720657
# 155  1990                Natural gas  1847.235712
# 156  1990                    Nuclear  2206.600396
# ..    ...                        ...          ...
# 395  2020                Natural gas  4054.010928
# 396  2020                    Nuclear   422.745655
# 397  2020       Renewables and waste  1376.778444
# 398  2020                Electricity     0.000000
# 399  2020                       Heat     0.000000
#
# [248 rows x 3 columns]

# %%
#data
#unit: petajoule(PJ)
source = supply_jp.iloc[:-1].rename_axis('year',axis=1).unstack().rename('supply').reset_index()
source = source[source.year>=1990]
source = source.rename(columns={'Product':'Source'})

source.year = source.year.astype(str)

sort_ = ['Crude, NGL and feedstocks',
         'Coal, peat and oil shale',
         'Natural gas', 
         'Renewables and waste',
         'Oil products', 
         'Electricity', 
         'Heat',
         'Nuclear']

xticks = np.arange(1990,2021,10).astype(str)
yticks = np.arange(0,28000,5000)

chart = alt.Chart(source).mark_bar().encode(
    x=alt.X('year',
            axis=alt.Axis(values=xticks, labelAngle=360)),
    y=alt.Y('sum(supply)',
            scale=alt.Scale(domain=(0, 28000)),
            axis=alt.Axis(values=yticks)),
    color=alt.Color('Source',sort=sort_),
    order=alt.Order('color_Source_sort_index:Q')
).configure_axis(
    grid=False
).properties(
    height=400,width=400,
    title="Japan's Energy Supply By Source")

chart
# Out:
# alt.Chart(...)

# %%
#chart.save('energy_supply.svg')
